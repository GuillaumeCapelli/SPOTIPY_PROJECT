# %%
id_list = []
for x in df.id:
    id_list.append(x)

# %%
audio_list = [] 
for x in range(0,len(id_list),100):
    if x+100 > len(id_list):
        y = len(id_list)
    else:
        y=x+100
    audio_list.extend(sp.audio_features(id_list[x:y]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 else:
#       6     y=x+100
# ----> 7 audio_list.extend(sp.audio_features(id_list[x:y]))
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1736, in Spotify.audio_features(self, tracks)
#    1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
# -> 1736     tlist = [self._get_id("track", t) for t in tracks]
#    1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1736, in <listcomp>(.0)
#    1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
# -> 1736     tlist = [self._get_id("track", t) for t in tracks]
#    1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1969, in Spotify._get_id(self, type, id)
#    1968 def _get_id(self, type, id):
# -> 1969     uri_match = re.search(Spotify._regex_spotify_uri, id)
#    1970     if uri_match is not None:
#    1971         uri_match_groups = uri_match.groupdict()
#
# File ~\anaconda3\lib\re.py:200, in search(pattern, string, flags)
#     197 def search(pattern, string, flags=0):
#     198     """Scan through string looking for a match to the pattern, returning
#     199     a Match object, or None if no match was found."""
# --> 200     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from clean_tracks import clean_tracks
from time import sleep

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

df = pd.read_csv("track_ids.csv")
df, summary = clean_tracks(df)

# %%
id_list = df.id   
audio_list = [] 
for x in range(0,len(id_list),100):
    if x+100 > len(id_list):
        y = len(id_list)
    else:
        y=x+100
    audio_list.extend(sp.audio_features(id_list[x:y]))
    sleep(2)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:868, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867 try:
# --> 868     retries = retries.increment(method, url, response=response, _pool=self)
#     869 except MaxRetryError:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=75JFxkI2RXiU7L9VXzMkle,0y1QJc3SJVPKJ1OvFmFqe6,10nyNJ6zNy2YVYLrcwLccB,1G391cbiT3v3Cywg8T7DM1,6ORqU0bHbVCRjXm9AjyHyZ,6ADSaE87h8Y3lccZlBJdXH,0AxdJGlXJjEUsNONDuT2pe,4RCWB3V8V0dignt99LZ8vH,5VEnzMXc8ocZko4M4TqnR2,2hnMS47jN0etwvFPzYk11f,7ygpwy2qP3NbrxVkHvUhXY,5cKhVlFn0Kuq68V56lSLvW,7nnWIPM5hwE3DaUBkvOIpy,63OQupATfueTdZMWTxW03A,3G69vJMWsX6ZohTykad2AU,1AdYZ6X00nXmO613Y7GJOl,1MTQHCpraD4S8g5PAFKzoj,3ZHfX6kbiY7JVsB63lLOLu,15VRO9CQwMpbqUYA7e6Hwg,3xXBsjrbG1xQIm1xv1cKOt,2JuasWPUodaUxf5nwNpciQ,0nLiqZ6A27jJri2VCalIUs,507bYMYfbm6sUS9iEAaeSd,6YIggUJW3ttAAPRdnki8RM,6i81qFkru6Kj1IEsB7KNp2,1BExV8JprNJLv
cHK,0wQnSQHf9Au29JuoIJ6owY,0PcLbCufEiO1GoGSMZynHD,6URw0a1glxSw4mgjdyKIYU,66ZtqKhYSA8XyPr0aAUFsm,3jqBLwtTiUYismDiZgAgPE,0BdZEQpJDKgj0DWBfiG1DH,35wUBvwdtylu6S1QO5cUur,77pB3BxEgaSZIbJ4uQflS8,7sIo6PV0QhGdla38aeWFaK,6Nh7AaiWaowVCL3EXQWd5P,2ngQWInvmJS2BieyK0l5Dg,0ooSj4Umkg2qncHeVlc5cL,73mad15Qg7WEy3fzKozA0T,0OR2mlRw9cEqKbbmhTF8K5,341Hd6DCztJk6CW6j0tTzz,0NjYY9gZdsxCH4EXGXVQaB,1gsaKZJuYe7R30yFdHo1aw,3mgFUpTSGwwyZL11YTu8cw,1xEoIbznfDQBmlkjywwQxE,0lq2sIuvudl50GBzcEZD9x,2rKILkEJB20rf6RLLmtDQm,6gjIGTrNOaf09o4Ps8b1KM,5QSGPhlzVUIqYjmjEANDdm,2I5S4UqzgMdooPBc31EmgX,4JTviRADkTsRQiP2XciEXn,7qc55PpGecCorFqxLGurp3,3CoPolybaWUbCTu4xm740m,4CvHynV8VqR0UoRyXr5X0L (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[12], line 8
#       6 else:
#       7     y=x+100
# ----> 8 audio_list.extend(sp.audio_features(id_list[x:y]))
#       9 sleep(2)
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1737, in Spotify.audio_features(self, tracks)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
# -> 1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#    1740 if "audio_features" in results:
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:307, in Spotify._internal_call(self, method, url, payload, params)
#     305     except (IndexError, AttributeError):
#     306         reason = None
# --> 307     raise SpotifyException(
#     308         429,
#     309         -1,
#     310         "%s:\n %s" % (request.path_url, "Max Retries"),
#     311         reason=reason
#     312     )
#     313 except ValueError:
#     314     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=75JFxkI2RXiU7L9VXzMkle,0y1QJc3SJVPKJ1OvFmFqe6,10nyNJ6zNy2YVYLrcwLccB,1G391cbiT3v3Cywg8T7DM1,6ORqU0bHbVCRjXm9AjyHyZ,6ADSaE87h8Y3lccZlBJdXH,0AxdJGlXJjEUsNONDuT2pe,4RCWB3V8V0dignt99LZ8vH,5VEnzMXc8ocZko4M4TqnR2,2hnMS47jN0etwvFPzYk11f,7ygpwy2qP3NbrxVkHvUhXY,5cKhVlFn0Kuq68V56lSLvW,7nnWIPM5hwE3DaUBkvOIpy,63OQupATfueTdZMWTxW03A,3G69vJMWsX6ZohTykad2AU,1AdYZ6X00nXmO613Y7GJOl,1MTQHCpraD4S8g5PAFKzoj,3ZHfX6kbiY7JVsB63lLOLu,15VRO9CQwMpbqUYA7e6Hwg,3xXBsjrbG1xQIm1xv1cKOt,2JuasWPUodaUxf5nwNpciQ,0nLiqZ6A27jJri2VCalIUs,507bYMYfbm6sUS9iEAaeSd,6YIggUJW3ttAAPRdnki8RM,6i81qFkru6Kj1IEsB7KNp2,1BExV8JprNJLvLeDE9qdEW,6vUPP