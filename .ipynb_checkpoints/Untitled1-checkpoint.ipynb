# %%
id_list = []
for x in df.id:
    id_list.append(x)

# %%
audio_list = [] 
for x in range(0,len(id_list),100):
    if x+100 > len(id_list):
        y = len(id_list)
    else:
        y=x+100
    audio_list.extend(sp.audio_features(id_list[x:y]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 else:
#       6     y=x+100
# ----> 7 audio_list.extend(sp.audio_features(id_list[x:y]))
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1736, in Spotify.audio_features(self, tracks)
#    1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
# -> 1736     tlist = [self._get_id("track", t) for t in tracks]
#    1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1736, in <listcomp>(.0)
#    1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
# -> 1736     tlist = [self._get_id("track", t) for t in tracks]
#    1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1969, in Spotify._get_id(self, type, id)
#    1968 def _get_id(self, type, id):
# -> 1969     uri_match = re.search(Spotify._regex_spotify_uri, id)
#    1970     if uri_match is not None:
#    1971         uri_match_groups = uri_match.groupdict()
#
# File ~\anaconda3\lib\re.py:200, in search(pattern, string, flags)
#     197 def search(pattern, string, flags=0):
#     198     """Scan through string looking for a match to the pattern, returning
#     199     a Match object, or None if no match was found."""
# --> 200     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from clean_tracks import clean_tracks
from time import sleep

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

df = pd.read_csv("track_ids.csv")
df, summary = clean_tracks(df)

# %%
id_list = df.id   
audio_list = [] 
for x in range(0,len(id_list),100):
    if x+100 > len(id_list):
        y = len(id_list)
    else:
        y=x+100
    audio_list.extend(sp.audio_features(id_list[x:y]))
    sleep(2)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:868, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#
B6lH,6ACaKnMLnhfwTYGtgG1al5,0t4J6vsfIb5wtYcSdht9yy,16etD0jjMNdKsHByc48tOY,6y9a7BsgmK4UFqBIHf9A7y,1GKKEH1kgP6litgarG1cty,3jWE8cJGhN8QxPItDUV6YZ,5t4fAVVsUzngHA39BVOcHK,0wQnSQHf9Au29JuoIJ6owY,0PcLbCufEiO1GoGSMZynHD,6URw0a1glxSw4mgjdyKIYU,66ZtqKhYSA8XyPr0aAUFsm,3jqBLwtTiUYismDiZgAgPE,0BdZEQpJDKgj0DWBfiG1DH,35wUBvwdtylu6S1QO5cUur,77pB3BxEgaSZIbJ4uQflS8,7sIo6PV0QhGdla38aeWFaK,6Nh7AaiWaowVCL3EXQWd5P,2ngQWInvmJS2BieyK0l5Dg,0ooSj4Umkg2qncHeVlc5cL,73mad15Qg7WEy3fzKozA0T,0OR2mlRw9cEqKbbmhTF8K5,341Hd6DCztJk6CW6j0tTzz,0NjYY9gZdsxCH4EXGXVQaB,1gsaKZJuYe7R30yFdHo1aw,3mgFUpTSGwwyZL11YTu8cw,1xEoIbznfDQBmlkjywwQxE,0lq2sIuvudl50GBzcEZD9x,2rKILkEJB20rf6RLLmtDQm,6gjIGTrNOaf09o4Ps8b1KM,5QSGPhlzVUIqYjmjEANDdm,2I5S4UqzgMdooPBc31EmgX,4JTviRADkTsRQiP2XciEXn,7qc55PpGecCorFqxLGurp3,3CoPolybaWUbCTu4xm740m,4CvHynV8VqR0UoRyXr5X0L:
#  Max Retries, reason: too many 429 error responses

# %%
import pandas as pd

audio_features = pd.read_csv('audio_features.csv')
track_clean = pd.read_csv('track_clean.csv')

merged_df = pd.merge(track_clean, audio_features, on='id', how='inner')

merged_df.set_index('name', inplace=True)

merged_df
# Out:
#                                          Unnamed: 0_x         artist  \
# name
# Shake It Off                                        0   Taylor Swift
# Baby                                                1  Justin Bieber
# Rolling in the Deep                                 2          Adele
# Starships                                           3    Nicki Minaj
# What Makes You Beautiful                            4  One Direction
# ...                                               ...            ...
# Right Round                                     10530       Flo Rida
# Fake It                                         10532        Seether
# We Are Never Ever Getting Back Together         10535   Taylor Swift
# Let Me Blow Ya Mind                             10536            Eve
# What's Luv? (feat. Ja-Rule & Ashanti)           10537        Fat Joe
#
#                                                                                      album  \
# name
# Shake It Off                                                                          1989
# Baby                                                                          My World 2.0
# Rolling in the Deep                                                                     21
# Starships                                                   Pink Friday ... Roman Reloaded
# What Makes You Beautiful                                                      Up All Night
# ...                                                                                    ...
# Right Round                                  R.O.O.T.S. (Route of Overcoming the Struggle)
# Fake It                                  Finding Beauty In Negative Spaces (Bonus Track...
# We Are Never Ever Getting Back Together            Red (Big Machine Radio Release Special)
# Let Me Blow Ya Mind                                                               Scorpion
# What's Luv? (feat. Ja-Rule & Ashanti)                    Jealous Ones Still Envy (J.O.S.E)
#
#                                         release_date  popularity  \
# name
# Shake It Off                              2014-10-27          87
# Baby                                      2010-01-01          84
# Rolling in the Deep                       2011-01-24          84
# Starships                                 2011-01-01          81
# What Makes You Beautiful                  2012-05-25          86
# ...                                              ...         ...
# Right Round                               2009-03-30          78
# Fake It                                   2007-01-01          78
# We Are Never Ever Getting Back Together   2012-10-22          78
# Let Me Blow Ya Mind                       2001-01-01          61
# What's Luv? (feat. Ja-Rule & Ashanti)     2001-12-04          78
#
#                                                              id  Unnamed: 0_y  \
# name
# Shake It Off                             0cqRj7pUJDkTCEsJkx8snD             0
# Baby                                     6epn3r7S14KUqlReYr77hA             1
# Rolling in the Deep                      4OSBTYWVwsQhGLF9NHvIbR             2
# Starships                                2EBCVPNAG46nbgs6jXPGvv             3
# What Makes You Beautiful                 4cluDES4hQEUhmXj6TXkSo             4
# ...                                                         ...           ...
# Right Round                              3GpbwCm3YxiWDvy29Uo3vP         10029
# Fake It                                  4eAwB5pnKFTmsgc3zWoYO0         10030
# We Are Never Ever Getting Back Together  0VwNdo84DaVYLIkbVO86ND         10031
# Let Me Blow Ya Mind                      4YA5g2UpNLmdql8fdrhlwY         10032
# What's Luv? (feat. Ja-Rule & Ashanti)    2mKouqwAIdQnMP43zxR89r         10033
#
#                                          danceability  energy  key  ...  \
# name                                                                ...
# Shake It Off                                    0.647   0.800    7  ...
# Baby                                            0.728   0.859    5  ...
# Rolling in the Deep                             0.730   0.769    8  ...
# Starships                                       0.747   0.716   11  ...
# What Makes You Beautiful                        0.726   0.787    4  ...
# ...                                               ...     ...  ...  ...
# Right Round                                     0.720   0.672    7  ...
# Fake It                                         0.611   0.950    8  ...
# We Are Never Ever Getting Back Together         0.628   0.676    7  ...
# Let Me Blow Ya Mind                             0.905   0.544    8  ...
# What's Luv? (feat. Ja-Rule & Ashanti)           0.835   0.707    8  ...
#
#                                          instrumentalness  liveness  valence  \
# name
# Shake It Off                                     0.000000    0.3340    0.942
# Baby                                             0.000000    0.1110    0.535
# Rolling in the Deep                              0.000000    0.0473    0.507
# Starships                                        0.000000    0.2510    0.751
# What Makes You Beautiful                         0.000000    0.0596    0.888
# ...                                                   ...       ...      ...
# Right Round                                      0.000000    0.2320    0.705
# Fake It                                          0.000002    0.0543    0.607
# We Are Never Ever Getting Back Together          0.000027    0.1210    0.750
# Let Me Blow Ya Mind                              0.000000    0.0618    0.882
# What's Luv? (feat. Ja-Rule & Ashanti)            0.000022    0.1080    0.919
#
#                                            tempo            type  \
# name
# Shake It Off                             160.078  audio_features
# Baby                                      65.043  audio_features
# Rolling in the Deep                      104.948  audio_features
# Starships                                125.008  audio_features
# What Makes You Beautiful                 124.990  audio_features
# ...                                          ...             ...
# Right Round                              124.986  audio_features
# Fake It                                  132.078  audio_features
# We Are Never Ever Getting Back Together   85.984  audio_features
# Let Me Blow Ya Mind                       90.026  audio_features
# What's Luv? (feat. Ja-Rule & Ashanti)     93.955  audio_features
#
#                                                                           uri  \
# name
# Shake It Off                             spotify:track:0cqRj7pUJDkTCEsJkx8snD
# Baby                                     spotify:track:6epn3r7S14KUqlReYr77hA
# Rolling in the Deep                      spotify:track:4OSBTYWVwsQhGLF9NHvIbR
# Starships                                spotify:track:2EBCVPNAG46nbgs6jXPGvv
# What Makes You Beautiful                 spotify:track:4cluDES4hQEUhmXj6TXkSo
# ...                                                                       ...
# Right Round                              spotify:track:3GpbwCm3YxiWDvy29Uo3vP
# Fake It                                  spotify:track:4eAwB5pnKFTmsgc3zWoYO0
# We Are Never Ever Getting Back Together  spotify:track:0VwNdo84DaVYLIkbVO86ND
# Let Me Blow Ya Mind                      spotify:track:4YA5g2UpNLmdql8fdrhlwY
# What's Luv? (feat. Ja-Rule & Ashanti)    spotify:track:2mKouqwAIdQnMP43zxR89r
#
#                                                                                 track_href  \
# name
# Shake It Off                             https://api.spotify.com/v1/tracks/0cqRj7pUJDkT...
# Baby                                     https://api.spotify.com/v1/tracks/6epn3r7S14KU...
# Rolling in the Deep                      https://api.spotify.com/v1/tracks/4OSBTYWVwsQh...
# Starships                                https://api.spotify.com/v1/tracks/2EBCVPNAG46n...
# What Makes You Beautiful                 https://api.spotify.com/v1/tracks/4cluDES4hQEU...
# ...                                                                                    ...
# Right Round                              https://api.spotify.com/v1/tracks/3GpbwCm3YxiW...
# Fake It                                  https://api.spotify.com/v1/tracks/4eAwB5pnKFTm...
# We Are Never Ever Getting Back Together  https://api.spotify.com/v1/tracks/0VwNdo84DaVY...
# Let Me Blow Ya Mind                      https://api.spotify.com/v1/tracks/4YA5g2UpNLmd...
# What's Luv? (feat. Ja-Rule & Ashanti)    https://api.spotify.com/v1/tracks/2mKouqwAIdQn...
#
#                                                                               analysis_url  \
# name
# Shake It Off                             https://api.spotify.com/v1/audio-analysis/0cqR...
# Baby                                     https://api.spotify.com/v1/audio-analysis/6epn...
# Rolling in the Deep                      https://api.spotify.com/v1/audio-analysis/4OSB...
# Starships                                https://api.spotify.com/v1/audio-analysis/2EBC...
# What Makes You Beautiful                 https://api.spotify.com/v1/audio-analysis/4clu...
# ...                                                                                    ...
# Right Round                              https://api.spotify.com/v1/audio-analysis/3Gpb...
# Fake It                                  https://api.spotify.com/v1/audio-analysis/4eAw...
# We Are Never Ever Getting Back Together  https://api.spotify.com/v1/audio-analysis/0VwN...
# Let Me Blow Ya Mind                      https://api.spotify.com/v1/audio-analysis/4YA5...
# What's Luv? (feat. Ja-Rule & Ashanti)    https://api.spotify.com/v1/audio-analysis/2mKo...
#
#                                         duration_ms time_signature
# name
# Shake It Off                                 219200              4
# Baby                                         214240              4
# Rolling in the Deep                          228093              4
# Starships                                    210627              4
# What Makes You Beautiful                     199987              4
# ...                                             ...            ...
# Right Round                                  204640              4
# Fake It                                      193893              4
# We Are Never Ever Getting Back Together      193147              4
# Let Me Blow Ya Mind                          230107              4
# What's Luv? (feat. Ja-Rule & Ashanti)        267093              4
#
# [10138 rows x 24 columns]

# %%
# ... [Your previous code here]

# Save the merged dataframe to a new CSV file
merged_df.to_csv('merged_output.csv')

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import pprint

data = pd.read_csv("merged_data.csv")

features = data[["danceability", "energy", "speechiness", "acousticness", "instrumentalness", "valence", "tempo"]]
df_cluster = data[['acousticness','danceability','energy','instrumentalness','speechiness','tempo','valence']].copy()

# %%
scaler = StandardScaler()
scaler.fit(df_cluster)
df_scaled = scaler.transform(df_cluster) #numpy array as result
df_scaled_df = pd.DataFrame(df_scaled, columns = df_cluster.columns) #converting to df to see 
display(df_cluster.head())
print()
display(df_scaled_df.head())
# Out:
#    acousticness  danceability  energy  instrumentalness  speechiness    tempo  \
# 0        0.0647         0.647   0.800               0.0       0.1650  160.078
# 1        0.0401         0.728   0.859               0.0       0.1370   65.043
# 2        0.1380         0.730   0.769               0.0       0.0298  104.948
# 3        0.1350         0.747   0.716               0.0       0.0750  125.008
# 4        0.0090         0.726   0.787               0.0       0.0737  124.990
#
#    valence
# 0    0.942
# 1    0.535
# 2    0.507
# 3    0.751
# 4    0.888
#    acousticness  danceability    energy  instrumentalness  speechiness  \
# 0     -0.951441      0.411066  0.927579         -0.796298     0.977710
# 1     -1.017741      0.833759  1.137103         -0.796298     0.649191
# 2     -0.753890      0.844196  0.817490         -0.796298    -0.608570
# 3     -0.761975      0.932909  0.629273         -0.796298    -0.078246
# 4     -1.101559      0.823322  0.881412         -0.796298    -0.093498
#
#       tempo   valence
# 0  1.373308  1.660847
# 1 -1.730987  0.241188
# 2 -0.427500  0.143521
# 3  0.227755  0.994619
# 4  0.227167  1.472489

# %%
K = range(2, 1000, 50)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234, n_init = 10)
    kmeans.fit(df_scaled_df)
    
    filename = "Model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(df_scaled_df, kmeans.predict(df_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
kmeans2 = KMeans(n_clusters=60, #bigger clusters going down
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=100, # less iterations slighty increases inertia
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(df_scaled_df)
print(kmeans2.inertia_)
# Out:
# 10708.921266782534

# %%
kmeans2.labels_
# Out:
# array([24, 45, 45, ..., 46, 29, 46])

# %%
kmeans2.cluster_centers_
# Out:
# array([[ 4.22213482e-01, -3.97100269e-01,  2.68809239e-01,
#         -7.58197677e-01, -3.49911352e-01,  1.27400244e-01,
#          6.63733952e-01],
#        [-7.14369338e-01,  1.11477996e+00,  3.65465836e-01,
#         -7.46363738e-01,  1.13932669e+00, -7.72785788e-01,
#          9.74916808e-01],
#        [ 1.41496820e+00, -6.56796515e-01, -1.45838078e+00,
#          1.37924465e+00, -4.85916996e-01, -1.47297220e+00,
#         -1.08767219e+00],
#        [-8.40192135e-01, -4.57680087e-01,  6.81734971e-01,
#          1.12921834e+00, -2.51848965e-01, -7.86830545e-01,
#         -2.42275964e-01],
#        [-8.80082100e-01,  3.95123270e-01,  8.15352074e-01,
#         -7.31983747e-01, -3.92636352e-01,  3.33401124e-01,
#          6.21493184e-01],
#        [-7.74250575e-01, -7.21020148e-02,  6.54887629e-01,
#         -6.96972093e-01, -1.35328773e-01,  1.65887698e+00,
#         -2.79496949e-01],
#        [ 9.78222517e-01, -1.30910513e+00, -1.03317578e+00,
#         -6.49951399e-01, -4.75218633e-01,  1.25135794e+00,
#         -8.88795576e-01],
#        [ 1.05228677e+00,  6.01809831e-01, -3.42883901e-01,
#          1.29326768e+00, -2.71715437e-01, -4.64284241e-01,
#          8.74683842e-01],
#         -8.05609253e-01],
#        [-4.90356653e-01,  1.24447314e+00, -2.22139849e-01,
#          1.24707795e+00,  1.60461703e+00,  1.40580961e-01,
#         -2.03426399e-01],
#        [-8.15653776e-01,  1.00793242e+00,  7.85597617e-01,
#         -6.87356935e-01,  1.17244471e+00,  4.14800887e-01,
#          2.10866511e-01],
#        [-3.20746049e-01,  3.57508065e-01,  2.50036735e-01,
#         -7.67548234e-01,  6.72680181e+00,  5.89718415e-01,
#         -1.08907507e-01],
#        [-1.05893602e+00,  4.63072096e-01,  1.18792317e+00,
#          1.21985213e+00, -2.70215304e-01,  5.23395751e-01,
#         -8.98700912e-01],
#        [-5.47784134e-01,  7.39053847e-01, -2.27764026e-02,
#          1.09077302e+00, -2.74140571e-01, -4.62681219e-01,
#          9.05381494e-01],
#        [ 1.14963726e+00, -4.44694476e-01, -1.14291936e+00,
#         -5.91620026e-01, -4.74947532e-01, -8.01156066e-01,
#         -7.30075504e-01],
#        [-6.07639887e-01, -3.24519095e-02,  5.77880593e-01,
#         -7.34630521e-01,  2.47984567e+00, -8.97551209e-01,
#         -3.17349682e-01],
#        [-8.04485734e-01, -2.62112193e-01,  9.12750954e-01,
#         -7.56139995e-01, -2.31267734e-01,  1.88933486e+00,
#          1.19581911e+00],
#        [-8.87820392e-01,  1.00319244e+00,  1.02236206e+00,
#         -6.90170836e-01, -1.70191400e-01,  2.83444664e-01,
#          1.39950927e+00],
#        [ 8.96830322e-01,  1.28910392e-01, -6.28444621e-01,
#         -7.13454300e-01, -3.32398132e-01, -9.40456484e-01,
#          6.01334983e-01],
#        [-4.52181127e-01,  2.76924208e-01, -6.01331915e-02,
#         -7.28231935e-01, -3.77041927e-01, -9.21323076e-01,
#          5.73046786e-01],
#        [-9.08937215e-01,  3.44306674e-03,  7.90763475e-01,
#          1.17173405e+00, -3.08644188e-01,  1.15122895e+00,
#          7.36709552e-01]])

# %%
kmeans2.cluster_centers_[0,:]
# Out:
# array([ 0.42221348, -0.39710027,  0.26880924, -0.75819768, -0.34991135,
#         0.12740024,  0.66373395])

# %%
clusters = kmeans2.predict(df_scaled_df)

pd.Series(clusters).value_counts().sort_index() #finding frequency
# Out:
# 0     151
# 1     182
# 2     275
# 3     110
# 4     309
# 5     141
# 6     131
# 7     125
# 8      79
# 9     142
# 10    171
# 11    158
# 12    266
# 13    122
# 14    155
# 15    175
# 16    182
# 17     79
# 18    108
# 19    176
# 20     84
# 21    181
# 22    402
# 23    176
# 24    147
# 25    139
# 26    247
# 27    208
# 28    111
# 29    307
# 30    161
# 31    157
# 32    108
# 33    252
# 34    158
# 35    374
# 36    101
# 37    199
# 38    200
# 39    146
# 40     41
# 41     84
# 42     70
# 43    131
# 44    121
# 45    221
# 46    253
# 47    185
# 48     44
# 49    154
# 50     19
# 51    264
# 52    108
# 53    249
# 54    106
# 55    154
# 56    284
# 57    232
# 58    207
# 59    116
# dtype: int64

# %%
data["cluster"] = clusters

# %%
data
# Out:
#                                           name         artist  \
# 0                                 Shake It Off   Taylor Swift
# 1                                         Baby  Justin Bieber
# 2                          Rolling in the Deep          Adele
# 3                                    Starships    Nicki Minaj
# 4                     What Makes You Beautiful  One Direction
# ...                                        ...            ...
# 10133                              Right Round       Flo Rida
# 10134                                  Fake It        Seether
# 10135  We Are Never Ever Getting Back Together   Taylor Swift
# 10136                      Let Me Blow Ya Mind            Eve
# 10137    What's Luv? (feat. Ja-Rule & Ashanti)        Fat Joe
#
#                                                    album release_date  \
# 0                                                   1989   2014-10-27
# 1                                           My World 2.0   2010-01-01
# 2                                                     21   2011-01-24
# 3                         Pink Friday ... Roman Reloaded   2011-01-01
# 4                                           Up All Night   2012-05-25
# ...                                                  ...          ...
# 10133      R.O.O.T.S. (Route of Overcoming the Struggle)   2009-03-30
# 10134  Finding Beauty In Negative Spaces (Bonus Track...   2007-01-01
# 10135            Red (Big Machine Radio Release Special)   2012-10-22
# 10136                                           Scorpion   2001-01-01
# 10137                  Jealous Ones Still Envy (J.O.S.E)   2001-12-04
#
#        popularity                      id  danceability  energy  key  \
# 0              87  0cqRj7pUJDkTCEsJkx8snD         0.647   0.800    7
# 1              84  6epn3r7S14KUqlReYr77hA         0.728   0.859    5
# 2              84  4OSBTYWVwsQhGLF9NHvIbR         0.730   0.769    8
# 3              81  2EBCVPNAG46nbgs6jXPGvv         0.747   0.716   11
# 4              86  4cluDES4hQEUhmXj6TXkSo         0.726   0.787    4
# ...           ...                     ...           ...     ...  ...
# 10133          78  3GpbwCm3YxiWDvy29Uo3vP         0.720   0.672    7
# 10134          78  4eAwB5pnKFTmsgc3zWoYO0         0.611   0.950    8
# 10135          78  0VwNdo84DaVYLIkbVO86ND         0.628   0.676    7
# 10136          61  4YA5g2UpNLmdql8fdrhlwY         0.905   0.544    8
# 10137          78  2mKouqwAIdQnMP43zxR89r         0.835   0.707    8
#
#        loudness  ...  liveness  valence    tempo            type  \
# 0        -5.384  ...    0.3340    0.942  160.078  audio_features
# 1        -5.237  ...    0.1110    0.535   65.043  audio_features
# 2        -5.114  ...    0.0473    0.507  104.948  audio_features
# 3        -2.457  ...    0.2510    0.751  125.008  audio_features
# 4        -2.494  ...    0.0596    0.888  124.990  audio_features
# ...         ...  ...       ...      ...      ...             ...
# 10133    -6.852  ...    0.2320    0.705  124.986  audio_features
# 10134    -3.509  ...    0.0543    0.607  132.078  audio_features
# 10135    -5.911  ...    0.1210    0.750   85.984  audio_features
# 10136    -4.354  ...    0.0618    0.882   90.026  audio_features
# 10137    -5.074  ...    0.1080    0.919   93.955  audio_features
#
#                                         uri  \
# 0      spotify:track:0cqRj7pUJDkTCEsJkx8snD
# 1      spotify:track:6epn3r7S14KUqlReYr77hA
# 2      spotify:track:4OSBTYWVwsQhGLF9NHvIbR
# 3      spotify:track:2EBCVPNAG46nbgs6jXPGvv
# 4      spotify:track:4cluDES4hQEUhmXj6TXkSo
# ...                                     ...
# 10133  spotify:track:3GpbwCm3YxiWDvy29Uo3vP
# 10134  spotify:track:4eAwB5pnKFTmsgc3zWoYO0
# 10135  spotify:track:0VwNdo84DaVYLIkbVO86ND
# 10136  spotify:track:4YA5g2UpNLmdql8fdrhlwY
# 10137  spotify:track:2mKouqwAIdQnMP43zxR89r
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0cqRj7pUJDkT...
# 1      https://api.spotify.com/v1/tracks/6epn3r7S14KU...
# 2      https://api.spotify.com/v1/tracks/4OSBTYWVwsQh...
# 3      https://api.spotify.com/v1/tracks/2EBCVPNAG46n...
# 4      https://api.spotify.com/v1/tracks/4cluDES4hQEU...
# ...                                                  ...
# 10133  https://api.spotify.com/v1/tracks/3GpbwCm3YxiW...
# 10134  https://api.spotify.com/v1/tracks/4eAwB5pnKFTm...
# 10135  https://api.spotify.com/v1/tracks/0VwNdo84DaVY...
# 10136  https://api.spotify.com/v1/tracks/4YA5g2UpNLmd...
# 10137  https://api.spotify.com/v1/tracks/2mKouqwAIdQn...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0cqR...      219200
# 1      https://api.spotify.com/v1/audio-analysis/6epn...      214240
# 2      https://api.spotify.com/v1/audio-analysis/4OSB...      228093
# 3      https://api.spotify.com/v1/audio-analysis/2EBC...      210627
# 4      https://api.spotify.com/v1/audio-analysis/4clu...      199987
# ...                                                  ...         ...
# 10133  https://api.spotify.com/v1/audio-analysis/3Gpb...      204640
# 10134  https://api.spotify.com/v1/audio-analysis/4eAw...      193893
# 10135  https://api.spotify.com/v1/audio-analysis/0VwN...      193147
# 10136  https://api.spotify.com/v1/audio-analysis/4YA5...      230107
# 10137  https://api.spotify.com/v1/audio-analysis/2mKo...      267093
#
#       time_signature cluster
# 0                  4      24
# 1                  4      45
# 2                  4      45
# 3                  4      56
# 4                  4      56
# ...              ...     ...
# 10133              4       4
# 10134              4       4
# 10135              4      46
# 10136              4      29
# 10137              4      46
#
# [10138 rows x 24 columns]

# %%
data[data['cluster'] == 21].sample(3) #select a sample from group 2
# Out:
#             name       artist           album release_date  popularity  \
# 8671        Just        Bicep         Just EP   2015-06-22          52
# 3056  In My Mind  Alfred Diaz  Smooth Groover   2021-08-27          23
# 3014    Bancroft       Lemtom     Bancroft EP   2020-10-27          54
#
#                           id  danceability  energy  key  loudness  ...  \
# 8671  7MHjC4y8tMWDV1xA3CpqzX         0.793   0.853    7    -6.303  ...
# 3056  63Q9H373B6dsRzymM0QHj7         0.800   0.886    3   -10.675  ...
# 3014  6WdBytQF1vUjjtZcCTqNRJ         0.794   0.693   10   -10.994  ...
#
#       liveness  valence    tempo            type  \
# 8671     0.032    0.620  120.002  audio_features
# 3056     0.320    0.762  122.986  audio_features
# 3014     0.249    0.614  129.009  audio_features
#
#                                        uri  \
# 8671  spotify:track:7MHjC4y8tMWDV1xA3CpqzX
# 3056  spotify:track:63Q9H373B6dsRzymM0QHj7
# 3014  spotify:track:6WdBytQF1vUjjtZcCTqNRJ
#
#                                              track_href  \
# 8671  https://api.spotify.com/v1/tracks/7MHjC4y8tMWD...
# 3056  https://api.spotify.com/v1/tracks/63Q9H373B6ds...
# 3014  https://api.spotify.com/v1/tracks/6WdBytQF1vUj...
#
#                                            analysis_url duration_ms  \
# 8671  https://api.spotify.com/v1/audio-analysis/7MHj...      372555
# 3056  https://api.spotify.com/v1/audio-analysis/63Q9...      348300
# 3014  https://api.spotify.com/v1/audio-analysis/6WdB...      448488
#
#      time_signature cluster
# 8671              4      21
# 3056              4      21
# 3014              4      21
#
# [3 rows x 24 columns]
