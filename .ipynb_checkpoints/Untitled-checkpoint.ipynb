# %%
pip install spotipy
# Out:
# ...
#                                               0.0/250.3 kB ? eta -:--:--
#      ------------------------------------- 250.3/250.3 kB 15.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Set up credentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

tracks=get_playlist_tracks("spotify", "6qpzqLTozSF6JAItQhWVNM")

# %%
tracks
# Out:
# [{'added_at': '2021-12-05T23:34:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/flanhelwiyd0xuu1nud7jtlqr'},
#    'href': 'https://api.spotify.com/v1/users/flanhelwiyd0xuu1nud7jtlqr',
#    'id': 'flanhelwiyd0xuu1nud7jtlqr',
#    'type': 'user',
#    'uri': 'spotify:user:flanhelwiyd0xuu1nud7jtlqr'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19ra5tSw0tWufvUp8GotLo'},
#       'href': 'https://api.spotify.com/v1/artists/19ra5tSw0tWufvUp8GotLo',
#       'id': '19ra5tSw0tWufvUp8GotLo',
#       'name': 'George Michael',
#       'type': 'artist',
#       'uri': 'spotify:artist:19ra5tSw0tWufvUp8GotLo'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/34K1Kvskt9arWy8E1Gz3Lw'},
#     'href': 'https://api.spotify.com/v1/albums/34K1Kvskt9arWy8E1Gz3Lw',
#     'id': '34K1Kvskt9arWy8E1Gz3Lw',
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Set up credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id, market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

tracks = get_playlist_tracks("spotify", "6qpzqLTozSF6JAItQhWVNM")

# Extract track details and transform into DataFrame
def tracks_to_dataframe(tracks):
    track_details = []
    for track in tracks:
        track_info = track['track']
        audio_features = sp.audio_features(track_info["id"])[0]
        
        details = {
            'name': track_info['name'],
            'artist': track_info['artists'][0]['name'],
            'album': track_info['album']['name'],
            'release_date': track_info['album']['release_date'],
            'popularity': track_info['popularity'],
            'danceability': audio_features['danceability'],
            'energy': audio_features['energy'],
            'key': audio_features['key'],
            'loudness': audio_features['loudness'],
            'mode': audio_features['mode'],
            'speechiness': audio_features['speechiness'],
            'acousticness': audio_features['acousticness'],
            'instrumentalness': audio_features['instrumentalness'],
            'liveness': audio_features['liveness'],
            'valence': audio_features['valence'],
            'tempo': audio_features['tempo'],
            'type': audio_features['type'],
            'id': audio_features['id'],
            'uri': audio_features['uri'],
            'track_href': audio_features['track_href'],
            'analysis_url': audio_features['analysis_url'],
            'duration_ms': audio_features['duration_ms'],
            'time_signature': audio_features['time_signature']
        }
        track_details.append(details)

    return pd.DataFrame(track_details)

df = tracks_to_dataframe(tracks)
df
# Out:
#                                       name           artist  \
# 0              Kissing a Fool - Remastered   George Michael
# 1                           I Will Survive    Gloria Gaynor
# 2   Nothing's Gonna Change My Love for You    George Benson
# 3                      Bad - 2012 Remaster  Michael Jackson
# 4                One More Try - Remastered   George Michael
# ..                                     ...              ...
# 68                               Angeleyes             ABBA
# 69                     Money, Money, Money             ABBA
# 70            Can't Get You out of My Head    Kylie Minogue
# 71                        Time in a Bottle        Jim Croce
# 72                               DO 4 LOVE     Snoh Aalegra
#
#                              album release_date  popularity  danceability  \
# 0                            Faith   1987-10-30          58         0.280
# 1                      Love Tracks   1978-11-27          76         0.770
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Set up credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id, market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

tracks = get_playlist_tracks("spotify", "6qpzqLTozSF6JAItQhWVNM")

# Extract track details and transform into DataFrame
def tracks_to_dataframe(tracks):
    track_details = []
    for track in tracks:
        track_info = track['track']
        audio_features = sp.audio_features(track_info["id"])[0]
        
        details = {
            'name': track_info['name'],
            'artist': track_info['artists'][0]['name'],
            'album': track_info['album']['name'],
            'release_date': track_info['album']['release_date'],
            'popularity': track_info['popularity']
        }
        track_details.append(details)

    return pd.DataFrame(track_details)

df = tracks_to_dataframe(tracks)
df
# Out:
#                                       name           artist  \
# 0              Kissing a Fool - Remastered   George Michael
# 1                           I Will Survive    Gloria Gaynor
# 2   Nothing's Gonna Change My Love for You    George Benson
# 3                      Bad - 2012 Remaster  Michael Jackson
# 4                One More Try - Remastered   George Michael
# ..                                     ...              ...
# 68                               Angeleyes             ABBA
# 69                     Money, Money, Money             ABBA
# 70            Can't Get You out of My Head    Kylie Minogue
# 71                        Time in a Bottle        Jim Croce
# 72                               DO 4 LOVE     Snoh Aalegra
#
#                              album release_date  popularity
# 0                            Faith   1987-10-30          58
# 1                      Love Tracks   1978-11-27          76
# 2                            20/20   1985-01-15          75
# ...

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

track_details = []

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id, market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
tracks = get_playlist_tracks("spotify", "37i9dQZF1DWWOaP4H0w5b0")

for track in tracks:
    track_info = track['track']
    details = {
        'name': track_info['name'],
        'artist': track_info['artists'][0]['name'],
        'album': track_info['album']['name'],
        'release_date': track_info['album']['release_date'],
        'popularity': track_info['popularity'],
        'id': track_info['id']
    }
    track_details.append(details)

    
df = pd.DataFrame(track_details)
df
# Out:
#                            name               artist  \
# 0             Master Of Puppets            Metallica
# 1   The Trooper - 2015 Remaster          Iron Maiden
# 2       Symphony Of Destruction             Megadeth
# 3                      Paranoid        Black Sabbath
# 4                          Walk              Pantera
# ..                          ...                  ...
# 95                        Bleed            Meshuggah
# 96               Heaven's a Lie          Lacuna Coil
# 97                        Detox  Strapping Young Lad
# 98            The Drapery Falls                Opeth
# 99              I Will Be Heard            Hatebreed
#
#                                                 album release_date  \
# 0       Master of Puppets (Remastered Deluxe Box Set)   1986-03-03
# 1                     Piece of Mind (2015 - Remaster)   1983-05-16
# 2   Countdown To Extinction (Expanded Edition - Re...   1992-07-14
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Set up credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id, market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

tracks = get_playlist_tracks("spotify", "7pqpRWcVxmerJJcRb31ciK")

# Extract track details and transform into DataFrame
def tracks_to_dataframe(tracks):
    track_details = []
    for track in tracks:
        track_info = track['track']
        audio_features = sp.audio_features(track_info["id"])[0]
        
        details = {
            'name': track_info['name'],
            'artist': track_info['artists'][0]['name'],
            'album': track_info['album']['name'],
            'release_date': track_info['album']['release_date'],
            'popularity': track_info['popularity'],
            'danceability': audio_features['danceability'],
            'energy': audio_features['energy'],
            'key': audio_features['key'],
            'loudness': audio_features['loudness'],
            'mode': audio_features['mode'],
            'speechiness': audio_features['speechiness'],
            'acousticness': audio_features['acousticness'],
            'instrumentalness': audio_features['instrumentalness'],
            'liveness': audio_features['liveness'],
            'valence': audio_features['valence'],
            'tempo': audio_features['tempo'],
            'type': audio_features['type'],
            'id': audio_features['id'],
            'uri': audio_features['uri'],
            'track_href': audio_features['track_href'],
            'analysis_url': audio_features['analysis_url'],
            'duration_ms': audio_features['duration_ms'],
            'time_signature': audio_features['time_signature']
        }
        track_details.append(details)

    return pd.DataFrame(track_details)

df = tracks_to_dataframe(tracks)
df
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# ...
